# %% [markdown]
# excel
# json
# xml
# text files

# %%
import pandas as pd

path = r"https://raw.githubusercontent.com/techficent/PythonDABatch/main/datasets/Loan_Status_Classification.csv"

df = pd.read_csv(path)

df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        1           1          0              0             6608
# 1         0        1           2          0              0             4226
# 2         1        1           0          1              0             3167
# 3         0        0           0          1              1             6950
# 4         0        1           0          1              0             3993
# ..      ...      ...         ...        ...            ...              ...
# 293       1        0           0          1              0             3846
# 294       0        0           0          1              0             2435
# 295       0        0           2          1              0             4923
# 296       0        1           3          0              0             2071
# 297       1        0           0          1              0             2378
#
# ...

# %%
excel_df = pd.read_excel("data.xlsx")

excel_df
# Out:
#          Name  Age  Salary
# 0     Harshit   32   45000
# 1        Ajay   31   50000
# 2  Shreyanshi   30   35000

# %%
excel_df[       ["Age",	"Salary"]           ].mean()
# Out:
# Age          31.000000
# Salary    43333.333333
# dtype: float64

# %%
json_df = pd.read_json("data.json")

json_df
# Out:
#          Name  Age  Salary
# 0     Harshit   32   45000
# 1        Ajay   32   45000
# 2  Shreyanshi   32   35000
